# %%
import os 
import sys

import sklearn as sk
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt 
import xgboost as xgb

from scipy.stats import kurtosis, entropy
from scipy.fft import fft

sys.path.append(r"c:\Users\keng-tse\Desktop\csi_tool") #這行為絕對路徑，如需使用，必須要修改為當前決路徑
import csi_tool
import denoise

# %%
base_path = r"C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv"
reference_points = {}

# 每個點的實際位置 (x, y)，基於 0.6m 的間距
spacing = 0.6  # 每隔 0.6m
coordinates = {
    # 下邊界 (1-10 和 40-31)
    1: (0, 0), 40: (0.6, 0), 39: (1.2, 0), 38: (1.8, 0), 37: (2.4, 0),
    36: (3.0, 0), 35: (3.6, 0), 34: (4.2, 0), 33: (4.8, 0), 32: (5.4, 0), 31: (6.0, 0),

    # 左邊界 (1-11)
    2: (0, 0.6), 3: (0, 1.2), 4: (0, 1.8), 5: (0, 2.4),
    6: (0, 3.0), 7: (0, 3.6), 8: (0, 4.2), 9: (0, 4.8), 10: (0, 5.4), 11: (0, 6.0),

    # 上邊界 (11-21)
    12: (0.6, 6.0), 13: (1.2, 6.0), 14: (1.8, 6.0), 15: (2.4, 6.0),
    16: (3.0, 6.0), 17: (3.6, 6.0), 18: (4.2, 6.0), 19: (4.8, 6.0),
    20: (5.4, 6.0), 21: (6.0, 6.0),

    # 右邊界 (21-31)
    22: (6.0, 5.4), 23: (6.0, 4.8), 24: (6.0, 4.2), 25: (6.0, 3.6),
    26: (6.0, 3.0), 27: (6.0, 2.4), 28: (6.0, 1.8), 29: (6.0, 1.2), 30: (6.0, 0.6),

    # 中間點 (41-49)
    41: (3.0, 0.6), 42: (3.0, 1.2), 43: (3.0, 1.8),
    44: (3.0, 2.4), 45: (3.0, 3.0), 46: (3.0, 3.6),
    47: (3.0, 4.2), 48: (3.0, 4.8), 49: (3.0, 5.4)
}

# 生成 reference_points 字典
for ref_id, coord in coordinates.items():
    folder_path = os.path.join(base_path, f"reference_point_{ref_id}.xlsx")
    reference_points[folder_path] = (ref_id, coord)

# 打印結果
for path, (ref_id, coord) in reference_points.items():
    print(f"Path: {path}, ID: {ref_id}, Coordinates: {coord}")
# Out:
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_1.xlsx, ID: 1, Coordinates: (0, 0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_40.xlsx, ID: 40, Coordinates: (0.6, 0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_39.xlsx, ID: 39, Coordinates: (1.2, 0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_38.xlsx, ID: 38, Coordinates: (1.8, 0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_37.xlsx, ID: 37, Coordinates: (2.4, 0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_36.xlsx, ID: 36, Coordinates: (3.0, 0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_35.xlsx, ID: 35, Coordinates: (3.6, 0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_34.xlsx, ID: 34, Coordinates: (4.2, 0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_33.xlsx, ID: 33, Coordinates: (4.8, 0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_32.xlsx, ID: 32, Coordinates: (5.4, 0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_31.xlsx, ID: 31, Coordinates: (6.0, 0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_2.xlsx, ID: 2, Coordinates: (0, 0.6)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_3.xlsx, ID: 3, Coordinates: (0, 1.2)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_4.xlsx, ID: 4, Coordinates: (0, 1.8)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_5.xlsx, ID: 5, Coordinates: (0, 2.4)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_6.xlsx, ID: 6, Coordinates: (0, 3.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_7.xlsx, ID: 7, Coordinates: (0, 3.6)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_8.xlsx, ID: 8, Coordinates: (0, 4.2)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_9.xlsx, ID: 9, Coordinates: (0, 4.8)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_10.xlsx, ID: 10, Coordinates: (0, 5.4)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_11.xlsx, ID: 11, Coordinates: (0, 6.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_12.xlsx, ID: 12, Coordinates: (0.6, 6.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_13.xlsx, ID: 13, Coordinates: (1.2, 6.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_14.xlsx, ID: 14, Coordinates: (1.8, 6.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_15.xlsx, ID: 15, Coordinates: (2.4, 6.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_16.xlsx, ID: 16, Coordinates: (3.0, 6.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_17.xlsx, ID: 17, Coordinates: (3.6, 6.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_18.xlsx, ID: 18, Coordinates: (4.2, 6.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_19.xlsx, ID: 19, Coordinates: (4.8, 6.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_20.xlsx, ID: 20, Coordinates: (5.4, 6.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_21.xlsx, ID: 21, Coordinates: (6.0, 6.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_22.xlsx, ID: 22, Coordinates: (6.0, 5.4)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_23.xlsx, ID: 23, Coordinates: (6.0, 4.8)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_24.xlsx, ID: 24, Coordinates: (6.0, 4.2)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_25.xlsx, ID: 25, Coordinates: (6.0, 3.6)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_26.xlsx, ID: 26, Coordinates: (6.0, 3.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_27.xlsx, ID: 27, Coordinates: (6.0, 2.4)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_28.xlsx, ID: 28, Coordinates: (6.0, 1.8)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_29.xlsx, ID: 29, Coordinates: (6.0, 1.2)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_30.xlsx, ID: 30, Coordinates: (6.0, 0.6)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_41.xlsx, ID: 41, Coordinates: (3.0, 0.6)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_42.xlsx, ID: 42, Coordinates: (3.0, 1.2)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_43.xlsx, ID: 43, Coordinates: (3.0, 1.8)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_44.xlsx, ID: 44, Coordinates: (3.0, 2.4)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_45.xlsx, ID: 45, Coordinates: (3.0, 3.0)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_46.xlsx, ID: 46, Coordinates: (3.0, 3.6)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_47.xlsx, ID: 47, Coordinates: (3.0, 4.2)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_48.xlsx, ID: 48, Coordinates: (3.0, 4.8)
# Path: C:\Users\keng-tse\Desktop\csi_tool\csi_dataset\localization_phone\1130_phone\80Mhz\csv\reference_point_49.xlsx, ID: 49, Coordinates: (3.0, 5.4)

# %%
def load_data(reference_points):
    data = []          # 用于存储所有数据
    rp_labels = []     # 用于存储参考点编号标签
    coord_labels = []  # 用于存储 (x, y) 坐标标签

    for path, (ref_id, coord) in reference_points.items():
        df = pd.read_excel(path)
        data.append(df.values)
        rp_labels.extend([ref_id] * len(df))
        coord_labels.extend([coord] * len(df))
    data = pd.DataFrame(np.vstack(data))
    rp_labels = pd.Series(rp_labels, name="Reference Point ID")
    coord_labels = pd.DataFrame(coord_labels, columns=["X", "Y"])
    return data, rp_labels, coord_labels

# %%
data, rp_labels, coord_labels = load_data(reference_points)

# %%
# 分離CFR和CIR數據
CFR_data = data.iloc[:, :234]  # 前 48 列是CFR
CIR_data = data.iloc[:, 234:]  # 後 48 列是CIR

# 將 CFR 和 CIR 轉換為 dB（如果需要）
def to_db(amplitude):
    # 防止對零取對數
    return 10 * np.log10(np.maximum(amplitude, 1e-10))

print(CFR_data.shape)

CFR_data_ham = denoise.hampel_filter(np.array(CFR_data))

cfr_db = to_db(CFR_data_ham)

#cir_db = to_db(CIR_data)


# 使用參考點 ID 作為分類標籤
y_class = rp_labels

# 使用座標作為回歸標籤
y_reg = coord_labels
# Out:
# (24427, 234)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Separate CFR data (first 48 columns)
#CFR_data = data.iloc[:, :48]

# Create a plot for each reference point label
unique_ref_ids = rp_labels.unique()

# Set up the figure and axis for plotting
plt.figure(figsize=(10, 6))

for ref_id in unique_ref_ids:
    # Select CFR data corresponding to each reference point
    ref_data = cfr_db[rp_labels == ref_id]
    
    # Plot the mean CFR for each reference point
    # You can also plot individual samples by looping through ref_data if you prefer
    plt.plot(np.mean(ref_data, axis=0), label=f"Ref ID: {ref_id}")

plt.title("CFR Data by Reference Point")
plt.xlabel("Subcarrier Index (1-48)")
plt.ylabel("Mean CFR Value")
plt.legend(title="Reference Points")
plt.show()

# %%
import os
import matplotlib.pyplot as plt

def save_individual_cfr_plots_by_label(data, rp_labels, save_dir=r"C:\Users\keng-tse\Desktop\csi-plot\csi80Hz\phase"):
    # Create directory to save files if it does not exist
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    # Separate CFR data (first 48 columns)
    #CFR_data = data.iloc[:, :48]

    # Iterate through each reference point ID and save a plot
    unique_ref_ids = rp_labels.unique()
    for ref_id in unique_ref_ids:
        # Select CFR data corresponding to the current reference point ID
        ref_data = data[rp_labels == ref_id]
        
        # Create a plot for the reference point
        plt.figure(figsize=(10, 6))

        # Plot each sample (line plot for each packet)
        for i in range(ref_data.shape[0]):
            plt.plot(ref_data[i, :], label=f"Sample {i+1}", alpha=0.6)

        plt.title(f"CFR Data for Reference Point {ref_id}")
        plt.xlabel("Subcarrier Index (1-48)")
        plt.ylabel("CFR Value")
        plt.grid(True)
        # plt.legend(title="Samples", bbox_to_anchor=(1.05, 1), loc='upper left')

        # Define the file name using the reference point ID
        file_name = f"{save_dir}/ref_point_{ref_id}.png"
        
        # Save the plot as a PNG image
        plt.savefig(file_name, bbox_inches="tight")
        plt.close()  # Close the plot to free up memory
        print(f"Saved CFR plot for Reference Point {ref_id} to {file_name}")

# Call the function to save CFR plots by reference point label
save_individual_cfr_plots_by_label(np.array(CIR_data), rp_labels)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 40
#      37         print(f"Saved CFR plot for Reference Point {ref_id} to {file_name}")
#      39 # Call the function to save CFR plots by reference point label
# ---> 40 save_individual_cfr_plots_by_label(CIR_data, rp_labels)
#
# Cell In[22], line 23, in save_individual_cfr_plots_by_label(data, rp_labels, save_dir)
#      21 # Plot each sample (line plot for each packet)
#      22 for i in range(ref_data.shape[0]):
# ---> 23     plt.plot(ref_data[i, :], label=f"Sample {i+1}", alpha=0.6)
#      25 plt.title(f"CFR Data for Reference Point {ref_id}")
#      26 plt.xlabel("Subcarrier Index (1-48)")
#
# File ~\anaconda3\envs\csitool\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\envs\csitool\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: (0, slice(None, None, None))

# %%
scaler = StandardScaler()
cfr_scaled = scaler.fit_transform(cfr_db)
cir_scaled = scaler.fit_transform(cir_db)

X = np.concat([cfr_db, cir_db], axis = 1)

# %%
X
# Out:
# array([[23.95089785, 24.0845192 , 24.12495478, ..., 12.77059652,
#          9.91051971, 12.66395606],
#        [26.10952168, 26.00862385, 25.95269495, ..., 14.76836565,
#         12.94968525, 11.0680428 ],
#        [24.90069889, 24.87239727, 24.60471038, ..., 15.40962832,
#         13.99213053, 17.04948129],
#        ...,
#        [25.58059693, 25.5123915 , 25.35044805, ..., 14.8170886 ,
#         11.19682106, 10.62665038],
#        [23.53380221, 23.41816155, 23.39623073, ..., 17.28113984,
#         14.07967412, 13.56687779],
#        [25.37674921, 25.30207256, 25.16248941, ..., 16.45407787,
#         15.15465257, 13.065125  ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(cfr_db, y_class, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

knn = KNeighborsClassifier(n_neighbors=3)


knn.fit(X_train, y_train)


y_pred = knn.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 94   0   0 ...   0   0   0]
#  [  0  97   0 ...   0   0   0]
#  [  0   0  88 ...   0   0   0]
#  ...
#  [  0   0   0 ...  76   0   0]
#  [  0   0   0 ...   0  86   0]
#  [  0   0   0 ...   0   0 109]]
#               precision    recall  f1-score   support
#
#            1       0.97      0.94      0.95       100
#            2       0.87      0.95      0.91       102
#            3       0.92      0.99      0.95        89
#            4       0.95      1.00      0.97       105
#            5       0.91      0.96      0.94        77
#            6       0.94      0.93      0.94       106
#            7       0.91      0.93      0.92       113
#            8       0.95      0.94      0.94        98
#            9       0.73      0.80      0.76        93
#           10       0.86      0.99      0.92       103
#           11       0.88      0.86      0.87       106
#           12       0.81      0.91      0.85       100
#           13       0.91      0.97      0.94       105
#           14       0.83      0.90      0.86        90
#           15       0.89      0.82      0.85       100
#           16       0.88      0.94      0.91       102
#           17       0.98      0.98      0.98        89
#           18       0.92      0.91      0.92       101
#           19       0.68      0.65      0.66        96
#           20       0.92      0.92      0.92        87
#           21       0.85      0.70      0.77       111
#           22       0.90      0.94      0.92       100
#           23       0.93      0.86      0.90        95
#           24       0.90      0.85      0.88       109
#           25       0.89      0.74      0.81        91
#           26       0.97      0.97      0.97        98
#           27       0.96      0.87      0.91        99
#           28       0.95      0.79      0.86        98
#           29       0.95      0.99      0.97        97
#           30       0.89      0.87      0.88        95
#           31       0.91      0.89      0.90        96
#           32       0.87      0.89      0.88        92
#           33       0.88      0.91      0.90       105
#           34       0.98      0.93      0.95       114
#           35       0.92      0.89      0.90       110
#           36       0.97      0.94      0.95       101
#           37       0.97      0.90      0.93       111
#           38       0.92      0.96      0.94        82
#           39       0.92      0.77      0.84        94
#           40       0.96      0.99      0.97        89
#           41       0.96      0.98      0.97       105
#           42       0.94      0.98      0.96        92
#           43       0.85      0.87      0.86        99
#           44       0.95      0.93      0.94       109
#           45       0.76      0.83      0.79        93
#           46       0.95      0.92      0.94       102
#           47       0.80      0.94      0.86        81
#           48       0.91      0.90      0.91        96
#           49       0.94      0.99      0.96       110
#
#     accuracy                           0.90      4836
#    macro avg       0.90      0.90      0.90      4836
# weighted avg       0.90      0.90      0.90      4836

# %%
from sklearn.preprocessing import LabelEncoder

xgb_model = xgb.XGBClassifier()

# 假設 labels 是你的原始標籤
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y_train)  # 編碼 y_train

# 重新訓練模型
xgb_model.fit(X_train, y_encoded)

# 在預測階段，將預測結果轉換回原始標籤
y_pred_encoded = xgb_model.predict(X_test)
y_pred = label_encoder.inverse_transform(y_pred_encoded)  # 轉換回原始標籤

# 計算準確度
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")

# 顯示分類報告和混淆矩陣
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 89.08%
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.96      0.94      0.95       100
#            2       0.90      0.92      0.91       102
#            3       0.92      0.96      0.94        89
#            4       0.91      0.99      0.95       105
#            5       0.96      0.91      0.93        77
#            6       0.87      0.95      0.91       106
#            7       0.92      0.94      0.93       113
#            8       0.96      0.88      0.91        98
#            9       0.72      0.76      0.74        93
#           10       0.91      0.93      0.92       103
#           11       0.92      0.86      0.89       106
#           12       0.81      0.88      0.85       100
#           13       0.97      0.96      0.97       105
#           14       0.89      0.87      0.88        90
#           15       0.89      0.83      0.86       100
#           16       0.87      0.85      0.86       102
#           17       0.97      1.00      0.98        89
#           18       0.98      0.92      0.95       101
#           19       0.62      0.69      0.65        96
#           20       0.88      0.85      0.87        87
#           21       0.70      0.77      0.73       111
#           22       0.86      0.91      0.88       100
#           23       0.87      0.92      0.89        95
#           24       0.93      0.91      0.92       109
#           25       0.78      0.71      0.75        91
#           26       0.98      0.97      0.97        98
#           27       0.96      0.90      0.93        99
#           28       0.97      0.80      0.88        98
#           29       0.96      0.98      0.97        97
#           30       0.87      0.83      0.85        95
#           31       0.87      0.85      0.86        96
#           32       0.96      0.92      0.94        92
#           33       0.89      0.93      0.91       105
#           34       0.94      0.92      0.93       114
#           35       0.87      0.84      0.85       110
#           36       0.97      0.91      0.94       101
#           37       0.89      0.87      0.88       111
#           38       0.90      0.84      0.87        82
#           39       0.94      0.84      0.89        94
#           40       0.95      0.98      0.96        89
#           41       0.91      0.94      0.93       105
#           42       0.89      0.96      0.92        92
#           43       0.85      0.89      0.87        99
#           44       0.97      0.95      0.96       109
#           45       0.75      0.76      0.76        93
#           46       0.92      0.91      0.92       102
#           47       0.79      0.89      0.84        81
#           48       0.91      0.83      0.87        96
#           49       0.89      0.97      0.93       110
#
#     accuracy                           0.89      4836
#    macro avg       0.89      0.89      0.89      4836
# weighted avg       0.89      0.89      0.89      4836
#
# Confusion Matrix:
# [[ 94   0   0 ...   0   0   0]
#  [  0  94   0 ...   0   0   0]
#  [  0   0  85 ...   0   0   0]
#  ...
#  [  0   0   0 ...  72   0   0]
#  [  0   0   0 ...   0  80   0]
#  [  0   0   0 ...   0   0 107]]
